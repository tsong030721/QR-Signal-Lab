# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from qr_signal_lab.ingestion.fetch_commodities import fetch_one, fetch_batch, fetch_batch_separate
from datetime import datetime

start, period = "2020-1-1", "1y"
print(fetch_batch_separate(["CL=F", "GC=F", "x"], start = start, period = period))
# Out:
# 1 Failed download:
# ['X']: YFTzMissingError('possibly delisted; no timezone found')
# ---------------------------------------------------------------------------
# EmptyData                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 from datetime import datetime
#       4 start, period = "2020-1-1", "1y"
# ----> 5 print(fetch_batch_separate(["CL=F", "GC=F", "x"], start = start, period = period))
#
# File /workspaces/QR-Signal-Lab/qr_signal_lab/ingestion/fetch_commodities.py:48, in fetch_batch_separate(symbols, start, end, period, interval)
#      46 df = []
#      47 for s in symbols:
# ---> 48     df.append(_yfdownload_wrapper([s], start, end, period, interval))
#      50 return df
#
# File /workspaces/QR-Signal-Lab/qr_signal_lab/ingestion/fetch_commodities.py:72, in _yfdownload_wrapper(symbols, start, end, period, interval)
#      70 if df.empty:
#      71     msg = f"{symbols[0]}." if len(symbols) == 1 else f"{len(symbols)} symbols."
# ...
